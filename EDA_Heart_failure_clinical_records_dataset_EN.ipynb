# %% [markdown]
# <a href="https://colab.research.google.com/github/MiroshnitshenkoC/Data-Science-Miroshnitshenko-/blob/main/EDA_Heart_failure_clinical_records_dataset_EN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🩺 Enhanced EDA Template for Medical Dataset (Google Colab)

# %%
# 1. Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from IPython.display import display, Image

# %%
# 2. Load dataset
# from google.colab import files
# uploaded = files.upload()
df = pd.read_csv('/heart_failure_clinical_records_dataset.csv')

# %% [markdown]
# ## 3. Basic Overview

# %%
display(df)
print(df.head(5))
print("\nDataset shape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nData types:\n", df.dtypes)
print("\nSummary info:")
df.info()
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %% [markdown]
# ## 4. Rename columns (if necessary)

# %%
# Example: df.rename(columns={'old_name': 'new_name'}, inplace=True)

# %% [markdown]
# ## 5. Check for missing or invalid data

# %%
print("\nMissing values:")
print(df.isnull().sum())
msno.matrix(df)
plt.show()
# Optional: df.replace('?', np.nan, inplace=True)
# Out:
# Missing values:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %% [markdown]
# ## 6. Impute or handle missing data (if needed)

# %%
# Example: df['column'].fillna(df['column'].median(), inplace=True)

# %% [markdown]
# ## 7. Drop duplicates and check again

# %%
df.drop_duplicates(inplace=True)
print("\nNew shape after removing duplicates:", df.shape)
# Out:
# New shape after removing duplicates: (299, 13)

# %% [markdown]
# ## 8. Univariate analysis

# %%
print(df.describe())
df.hist(bins=20, figsize=(15, 10))
plt.tight_layout()
plt.show()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %% [markdown]
# ## 9. Categorical variables analysis

# %%
# Example: print(df['sex'].value_counts())

# %% [markdown]
# ## 10. Bivariate analysis and correlation

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ## 11. Outliers (boxplots)

# %%
# Example: sns.boxplot(x=df['creatinine_phosphokinase'])

# %% [markdown]
# ## 12. Final notes and insights

# %% [markdown]
# - Which variables are most important?
# - Are there any surprising correlations?
# - What features need transformation or normalization?
# - What next steps would you take?
